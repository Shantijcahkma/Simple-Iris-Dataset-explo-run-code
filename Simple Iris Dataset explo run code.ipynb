# %% [markdown]
# **Simple Iris dataset exploration using Python**
# Source blog: https://www.geeksforgeeks.org/python-basics-of-pandas-using-iris-dataset/
# Source data: https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv
#
# Demonstrate basic dataset loading and exploration functions of Python
#
# **About the Iris dataset:**
# Iris dataset is the starting dataset for Analytics and Machine Learning. For starting your career in Analytics and Machine Learning you will be practicing basic ML algorithms on this famous dataset.
#
# Iris is a flowering plant, the researchers have measured various features of the different iris flowers and recorded digitally. Iris dataset contains five columns. First 4 columns are the features which determine the species and the 5th column contains the name of the species:
# 1. Petal Length,
# 2. Petal Width,
# 3. Sepal Length,
# 4. Sepal Width and
# 5. Species Type.

# %%
# Import required libraries - in this case pandas to manage dataframe
import pandas as pd

# %%
# Usig pandas read the csv file from source URL in github
# We are saving the dataset in a dataframe called data.
data = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# Check if data has been read correctly by seeing the top 10 rows of dataframe
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# If you want to see the number of columns and column names and type of data
data.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# Let us rename the column variety to correct term Species
data.rename(columns = {'variety':'Species'}, inplace = True)
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    Species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# To see the number of rows & columns of the dataframe
# The first one is the number of rows and
# the other one is the number of columns.
data.shape
# Out:
# (150, 5)

# %%
# To display the full dataset just type the name of the dataset
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    Species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# We can insert a new column with row number and give it a name Id. 
# Please note Dataframe starts with Index 0 
import numpy as np
data.insert(loc=0, column='Id', value=np.arange(len(data)))
data.head()
# Out:
#    Id  sepal.length  sepal.width  petal.length  petal.width Species
# 0   0           5.1          3.5           1.4          0.2  Setosa
# 1   1           4.9          3.0           1.4          0.2  Setosa
# 2   2           4.7          3.2           1.3          0.2  Setosa
# 3   3           4.6          3.1           1.5          0.2  Setosa
# 4   4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# **Slicing the rows.**
# Slicing means if you want to print or work upon a particular group of lines that is from 10th row to 20th row.

# %%
#data[start:end]
#start is inclusive whereas end is exclusive
print(data[10:21])
# it will print the rows from 10 to 20.
# Out:
#     Id  sepal.length  sepal.width  petal.length  petal.width Species
# 10  10           5.4          3.7           1.5          0.2  Setosa
# 11  11           4.8          3.4           1.6          0.2  Setosa
# 12  12           4.8          3.0           1.4          0.1  Setosa
# 13  13           4.3          3.0           1.1          0.1  Setosa
# 14  14           5.8          4.0           1.2          0.2  Setosa
# 15  15           5.7          4.4           1.5          0.4  Setosa
# 16  16           5.4          3.9           1.3          0.4  Setosa
# 17  17           5.1          3.5           1.4          0.3  Setosa
# 18  18           5.7          3.8           1.7          0.3  Setosa
# 19  19           5.1          3.8           1.5          0.3  Setosa
# 20  20           5.4          3.4           1.7          0.2  Setosa

# %%
# To save the data in another dataframe for further use in analysis use below code
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     Id  sepal.length  sepal.width  petal.length  petal.width Species
# 10  10           5.4          3.7           1.5          0.2  Setosa
# 11  11           4.8          3.4           1.6          0.2  Setosa
# 12  12           4.8          3.0           1.4          0.1  Setosa
# 13  13           4.3          3.0           1.1          0.1  Setosa
# 14  14           5.8          4.0           1.2          0.2  Setosa
# 15  15           5.7          4.4           1.5          0.4  Setosa
# 16  16           5.4          3.9           1.3          0.4  Setosa
# 17  17           5.1          3.5           1.4          0.3  Setosa
# 18  18           5.7          3.8           1.7          0.3  Setosa
# 19  19           5.1          3.8           1.5          0.3  Setosa
# 20  20           5.4          3.4           1.7          0.2  Setosa

# %%
# To work on only certain columns say ID & Species name
# we will save it in a another variable named "specific_data"

specific_data=data[["Id","Species"]]
#data[["column_name1","column_name2","column_name3"]]

#now we will print the first 10 columns of the specific_data dataframe.
print(specific_data.head(10))
# Out:
#    Id Species
# 0   0  Setosa
# 1   1  Setosa
# 2   2  Setosa
# 3   3  Setosa
# 4   4  Setosa
# 5   5  Setosa
# 6   6  Setosa
# 7   7  Setosa
# 8   8  Setosa
# 9   9  Setosa

# %% [markdown]
# **Filtering:** Displaying the specific rows using “iloc” and “loc” functions.
#
# The “loc” functions use the index name of the row to display the particular row of the dataset.
#
# The “iloc” functions use the index integer of the row, which gives complete information about the row.

# %%
# here we will use iloc

data.iloc[5]
#it will display records only with species "Iris-setosa".
data.loc[data["Species"] == "Setosa"]
# Out:
#     Id  sepal.length  sepal.width  petal.length  petal.width Species
# 0    0           5.1          3.5           1.4          0.2  Setosa
# 1    1           4.9          3.0           1.4          0.2  Setosa
# 2    2           4.7          3.2           1.3          0.2  Setosa
# 3    3           4.6          3.1           1.5          0.2  Setosa
# 4    4           5.0          3.6           1.4          0.2  Setosa
# 5    5           5.4          3.9           1.7          0.4  Setosa
# 6    6           4.6          3.4           1.4          0.3  Setosa
# 7    7           5.0          3.4           1.5          0.2  Setosa
# 8    8           4.4          2.9           1.4          0.2  Setosa
# 9    9           4.9          3.1           1.5          0.1  Setosa
# 10  10           5.4          3.7           1.5          0.2  Setosa
# 11  11           4.8          3.4           1.6          0.2  Setosa
# 12  12           4.8          3.0           1.4          0.1  Setosa
# 13  13           4.3          3.0           1.1          0.1  Setosa
# 14  14           5.8          4.0           1.2          0.2  Setosa
# 15  15           5.7          4.4           1.5          0.4  Setosa
# 16  16           5.4          3.9           1.3          0.4  Setosa
# 17  17           5.1          3.5           1.4          0.3  Setosa
# 18  18           5.7          3.8           1.7          0.3  Setosa
# 19  19           5.1          3.8           1.5          0.3  Setosa
# 20  20           5.4          3.4           1.7          0.2  Setosa
# 21  21           5.1          3.7           1.5          0.4  Setosa
# 22  22           4.6          3.6           1.0          0.2  Setosa
# 23  23           5.1          3.3           1.7          0.5  Setosa
# 24  24           4.8          3.4           1.9          0.2  Setosa
# 25  25           5.0          3.0           1.6          0.2  Setosa
# 26  26           5.0          3.4           1.6          0.4  Setosa
# 27  27           5.2          3.5           1.5          0.2  Setosa
# 28  28           5.2          3.4           1.4          0.2  Setosa
# 29  29           4.7          3.2           1.6          0.2  Setosa
# 30  30           4.8          3.1           1.6          0.2  Setosa
# 31  31           5.4          3.4           1.5          0.4  Setosa
# 32  32           5.2          4.1           1.5          0.1  Setosa
# 33  33           5.5          4.2           1.4          0.2  Setosa
# 34  34           4.9          3.1           1.5          0.2  Setosa
# 35  35           5.0          3.2           1.2          0.2  Setosa
# 36  36           5.5          3.5           1.3          0.2  Setosa
# 37  37           4.9          3.6           1.4          0.1  Setosa
# 38  38           4.4          3.0           1.3          0.2  Setosa
# 39  39           5.1          3.4           1.5          0.2  Setosa
# 40  40           5.0          3.5           1.3          0.3  Setosa
# 41  41           4.5          2.3           1.3          0.3  Setosa
# 42  42           4.4          3.2           1.3          0.2  Setosa
# 43  43           5.0          3.5           1.6          0.6  Setosa
# 44  44           5.1          3.8           1.9          0.4  Setosa
# 45  45           4.8          3.0           1.4          0.3  Setosa
# 46  46           5.1          3.8           1.6          0.2  Setosa
# 47  47           4.6          3.2           1.4          0.2  Setosa
# 48  48           5.3          3.7           1.5          0.2  Setosa
# 49  49           5.0          3.3           1.4          0.2  Setosa

# %%
# To see which unique type of labels (values) are in a column & count them by Species
#In this dataset we will work on the Species column, it will count number of times a particular species has occurred.
data["Species"].value_counts()
#it will display in descending order.
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# **Calculating sum, mean and mode of a particular column.**
# We can also calculate the sum, mean and mode of any integer columns as I have done in the following code.

# %%
# data["column_name"].sum(
sum_data = data["sepal.length"].sum()
mean_data = data["sepal.length"].mean()
median_data = data["sepal.length"].median()

print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333334
# Median: 5.8

# %% [markdown]
# **Extracting minimum and maximum from a column.**
# Identifying minimum and maximum integer, from a particular column or row can also be done in a dataset.

# %%
min_data=data["sepal.length"].min()
max_data=data["sepal.length"].max()

print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 7.9

# %% [markdown]
# **Adding a column to the dataset.**
# If want to add a new column in our dataset, as we are doing any calculations or extracting some information from the dataset, and if you want to save it a new column. This can be done by the following code by taking a case where we have added all integer values of all columns.
#
# For example, if we want to add a column let say "total_values", that means if you want to add all the integer value of that particular row and get total answer in the new column "total_values".
#
# First we will extract the columns which have integer values.

# %%
cols = data.columns

# it will print the list of column names.
print(cols)

# we will take that columns which have integer values.
cols = cols[1:5]

# we will save it in the new dataframe variable
data1 = data[cols]

# now adding new column "total_values" to dataframe data.
data["total_values"]=data1[cols].sum(axis=1)

# here axis=1 means you are working in rows,
# whereas axis=0 means you are working in columns.

# See the new dataframe with total_values column
data
# Out:
# Index(['Id', 'sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'Species'],
#       dtype='object')
#       Id  sepal.length  sepal.width  petal.length  petal.width    Species  \
# 0      0           5.1          3.5           1.4          0.2     Setosa
# 1      1           4.9          3.0           1.4          0.2     Setosa
# 2      2           4.7          3.2           1.3          0.2     Setosa
# 3      3           4.6          3.1           1.5          0.2     Setosa
# 4      4           5.0          3.6           1.4          0.2     Setosa
# ..   ...           ...          ...           ...          ...        ...
# 145  145           6.7          3.0           5.2          2.3  Virginica
# 146  146           6.3          2.5           5.0          1.9  Virginica
# 147  147           6.5          3.0           5.2          2.0  Virginica
# 148  148           6.2          3.4           5.4          2.3  Virginica
# 149  149           5.9          3.0           5.1          1.8  Virginica
#
#      total_values
# 0            10.2
# 1             9.5
# 2             9.4
# 3             9.4
# 4            10.2
# ..            ...
# 145          17.2
# 146          15.7
# 147          16.7
# 148          17.3
# 149          15.8
#
# [150 rows x 7 columns]

# %%
# Checking for null values
# Note: Null means nothing exists in the cell. Zero is not a null value
# So columnwise we will add any record that has any NA ie. Null values & check
data.isnull().sum()
# Out:
# Id              0
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# Species         0
# total_values    0
# dtype: int64

# %%
# To check correlation between each feature
data.corr(method='pearson')
# Out:
# /var/folders/ty/dyrr0z3n5sd444c4606ckkww0000gn/T/ipykernel_13528/247177830.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr(method='pearson')
#                     Id  sepal.length  sepal.width  petal.length  petal.width  \
# Id            1.000000      0.716676    -0.402301      0.882637     0.900027
# sepal.length  0.716676      1.000000    -0.117570      0.871754     0.817941
# sepal.width  -0.402301     -0.117570     1.000000     -0.428440    -0.366126
# petal.length  0.882637      0.871754    -0.428440      1.000000     0.962865
# petal.width   0.900027      0.817941    -0.366126      0.962865     1.000000
# total_values  0.852260      0.940914    -0.223093      0.971379     0.953885
#
#               total_values
# Id                0.852260
# sepal.length      0.940914
# sepal.width      -0.223093
# petal.length      0.971379
# petal.width       0.953885
# total_values      1.000000

# %% [markdown]
# The above output dataframe can be seen as for any cell, row variable correlation with the column variable is the value of the cell. The correlation of a variable with itself is 1. For that reason, all the diagonal values are 1.00.
#
# **Multivariate Analysis:**
# Pair plot is used to visualize the relationship between each type of column variable. It is implemented only by one line code, which is as follows :

# %%
# To drqaw pair plots
g = sns.pairplot(data,hue="Species")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # To drqaw pair plots
# ----> 2 g = sns.pairplot(data,hue="Species")
#
# NameError: name 'sns' is not defined

# %% [markdown]
# **Formatting and Styling:**
#
# Conditional formatting can be applied to your dataframe by using Dataframe.style function. Styling is used to visualize your data, and most convenient way of visualizing your dataset is in tabular form.
#
# Here we will highlight the minimum and maximum from each row and columns.
#
# Now we will highlight the maximum and minimum column-wise, row-wise, and the whole dataframe wise using Styler.apply function. The Styler.apply function passes each column or row of the dataframe depending upon the keyword argument axis. For column-wise use axis=0, row-wise use axis=1, and for the entire table at once use axis=None.

# %%
# This is an example of rendering a datagram, which is not visualised by any styles.
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ee12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ee12_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_9ee12_level0_col1" class="col_heading level0 col1" >sepal.length</th>
#       <th id="T_9ee12_level0_col2" class="col_heading level0 col2" >sepal.width</th>
#       <th id="T_9ee12_level0_col3" class="col_heading level0 col3" >petal.length</th>
#       <th id="T_9ee12_level0_col4" class="col_heading level0 col4" >petal.width</th>
#       <th id="T_9ee12_level0_col5" class="col_heading level0 col5" >Species</th>
#       <th id="T_9ee12_level0_col6" class="col_heading level0 col6" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ee12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ee12_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ee12_row0_col1" class="data row0 col1" >5.100000</td>
#       <td id="T_9ee12_row0_col2" class="data row0 col2" >3.500000</td>
#       <td id="T_9ee12_row0_col3" class="data row0 col3" >1.400000</td>
#       <td id="T_9ee12_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_9ee12_row0_col5" class="data row0 col5" >Setosa</td>
#       <td id="T_9ee12_row0_col6" class="data row0 col6" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ee12_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9ee12_row1_col1" class="data row1 col1" >4.900000</td>
#       <td id="T_9ee12_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_9ee12_row1_col3" class="data row1 col3" >1.400000</td>
#       <td id="T_9ee12_row1_col4" class="data row1 col4" >0.200000</td>
#       <td id="T_9ee12_row1_col5" class="data row1 col5" >Setosa</td>
#       <td id="T_9ee12_row1_col6" class="data row1 col6" >9.500000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9ee12_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9ee12_row2_col1" class="data row2 col1" >4.700000</td>
#       <td id="T_9ee12_row2_col2" class="data row2 col2" >3.200000</td>
#       <td id="T_9ee12_row2_col3" class="data row2 col3" >1.300000</td>
#       <td id="T_9ee12_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_9ee12_row2_col5" class="data row2 col5" >Setosa</td>
#       <td id="T_9ee12_row2_col6" class="data row2 col6" >9.400000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9ee12_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9ee12_row3_col1" class="data row3 col1" >4.600000</td>
#       <td id="T_9ee12_row3_col2" class="data row3 col2" >3.100000</td>
#       <td id="T_9ee12_row3_col3" class="data row3 col3" >1.500000</td>
#       <td id="T_9ee12_row3_col4" class="data row3 col4" >0.200000</td>
#       <td id="T_9ee12_row3_col5" class="data row3 col5" >Setosa</td>
#       <td id="T_9ee12_row3_col6" class="data row3 col6" >9.400000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9ee12_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_9ee12_row4_col1" class="data row4 col1" >5.000000</td>
#       <td id="T_9ee12_row4_col2" class="data row4 col2" >3.600000</td>
#       <td id="T_9ee12_row4_col3" class="data row4 col3" >1.400000</td>
#       <td id="T_9ee12_row4_col4" class="data row4 col4" >0.200000</td>
#       <td id="T_9ee12_row4_col5" class="data row4 col5" >Setosa</td>
#       <td id="T_9ee12_row4_col6" class="data row4 col6" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9ee12_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_9ee12_row5_col1" class="data row5 col1" >5.400000</td>
#       <td id="T_9ee12_row5_col2" class="data row5 col2" >3.900000</td>
#       <td id="T_9ee12_row5_col3" class="data row5 col3" >1.700000</td>
#       <td id="T_9ee12_row5_col4" class="data row5 col4" >0.400000</td>
#       <td id="T_9ee12_row5_col5" class="data row5 col5" >Setosa</td>
#       <td id="T_9ee12_row5_col6" class="data row5 col6" >11.400000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9ee12_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_9ee12_row6_col1" class="data row6 col1" >4.600000</td>
#       <td id="T_9ee12_row6_col2" class="data row6 col2" >3.400000</td>
#       <td id="T_9ee12_row6_col3" class="data row6 col3" >1.400000</td>
#       <td id="T_9ee12_row6_col4" class="data row6 col4" >0.300000</td>
#       <td id="T_9ee12_row6_col5" class="data row6 col5" >Setosa</td>
#       <td id="T_9ee12_row6_col6" class="data row6 col6" >9.700000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9ee12_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_9ee12_row7_col1" class="data row7 col1" >5.000000</td>
#       <td id="T_9ee12_row7_col2" class="data row7 col2" >3.400000</td>
#       <td id="T_9ee12_row7_col3" class="data row7 col3" >1.500000</td>
#       <td id="T_9ee12_row7_col4" class="data row7 col4" >0.200000</td>
#       <td id="T_9ee12_row7_col5" class="data row7 col5" >Setosa</td>
#       <td id="T_9ee12_row7_col6" class="data row7 col6" >10.100000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9ee12_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_9ee12_row8_col1" class="data row8 col1" >4.400000</td>
#       <td id="T_9ee12_row8_col2" class="data row8 col2" >2.900000</td>
#       <td id="T_9ee12_row8_col3" class="data row8 col3" >1.400000</td>
#       <td id="T_9ee12_row8_col4" class="data row8 col4" >0.200000</td>
#       <td id="T_9ee12_row8_col5" class="data row8 col5" >Setosa</td>
#       <td id="T_9ee12_row8_col6" class="data row8 col6" >8.900000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9ee12_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_9ee12_row9_col1" class="data row9 col1" >4.900000</td>
#       <td id="T_9ee12_row9_col2" class="data row9 col2" >3.100000</td>
#       <td id="T_9ee12_row9_col3" class="data row9 col3" >1.500000</td>
#       <td id="T_9ee12_row9_col4" class="data row9 col4" >0.100000</td>
#       <td id="T_9ee12_row9_col5" class="data row9 col5" >Setosa</td>
#       <td id="T_9ee12_row9_col6" class="data row9 col6" >9.600000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9ee12_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_9ee12_row10_col1" class="data row10 col1" >5.400000</td>
#       <td id="T_9ee12_row10_col2" class="data row10 col2" >3.700000</td>
#       <td id="T_9ee12_row10_col3" class="data row10 col3" >1.500000</td>
#       <td id="T_9ee12_row10_col4" class="data row10 col4" >0.200000</td>
#       <td id="T_9ee12_row10_col5" class="data row10 col5" >Setosa</td>
#       <td id="T_9ee12_row10_col6" class="data row10 col6" >10.800000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9ee12_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_9ee12_row11_col1" class="data row11 col1" >4.800000</td>
#       <td id="T_9ee12_row11_col2" class="data row11 col2" >3.400000</td>
#       <td id="T_9ee12_row11_col3" class="data row11 col3" >1.600000</td>
#       <td id="T_9ee12_row11_col4" class="data row11 col4" >0.200000</td>
#       <td id="T_9ee12_row11_col5" class="data row11 col5" >Setosa</td>
#       <td id="T_9ee12_row11_col6" class="data row11 col6" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9ee12_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9ee12_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_9ee12_row12_col1" class="data row12 col1" >4.800000</td>
#       <td id="

# %%
# We will only select columns that are numnerical
highlight_data=data[["sepal.length","sepal.width","petal.length","petal.width"]]
print(highlight_data.head(10))
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4
# 6           4.6          3.4           1.4          0.3
# 7           5.0          3.4           1.5          0.2
# 8           4.4          2.9           1.4          0.2
# 9           4.9          3.1           1.5          0.1

# %%
# We will highlight in light green those cells which have highest values
highlight_data.head(50).style.highlight_max(color='lightgreen', axis=0)
#highlight_data.head(50).style.highlight_max(color='lightgreen', axis=1)
#highlight_data.head(50).style.highlight_max(color='lightgreen', axis=None)
# Out:
# <style type="text/css">
# #T_a8573_row14_col0, #T_a8573_row15_col1, #T_a8573_row24_col2, #T_a8573_row43_col3, #T_a8573_row44_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8573">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8573_level0_col0" class="col_heading level0 col0" >sepal.length</th>
#       <th id="T_a8573_level0_col1" class="col_heading level0 col1" >sepal.width</th>
#       <th id="T_a8573_level0_col2" class="col_heading level0 col2" >petal.length</th>
#       <th id="T_a8573_level0_col3" class="col_heading level0 col3" >petal.width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8573_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8573_row0_col0" class="data row0 col0" >5.100000</td>
#       <td id="T_a8573_row0_col1" class="data row0 col1" >3.500000</td>
#       <td id="T_a8573_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_a8573_row0_col3" class="data row0 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8573_row1_col0" class="data row1 col0" >4.900000</td>
#       <td id="T_a8573_row1_col1" class="data row1 col1" >3.000000</td>
#       <td id="T_a8573_row1_col2" class="data row1 col2" >1.400000</td>
#       <td id="T_a8573_row1_col3" class="data row1 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8573_row2_col0" class="data row2 col0" >4.700000</td>
#       <td id="T_a8573_row2_col1" class="data row2 col1" >3.200000</td>
#       <td id="T_a8573_row2_col2" class="data row2 col2" >1.300000</td>
#       <td id="T_a8573_row2_col3" class="data row2 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8573_row3_col0" class="data row3 col0" >4.600000</td>
#       <td id="T_a8573_row3_col1" class="data row3 col1" >3.100000</td>
#       <td id="T_a8573_row3_col2" class="data row3 col2" >1.500000</td>
#       <td id="T_a8573_row3_col3" class="data row3 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8573_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_a8573_row4_col1" class="data row4 col1" >3.600000</td>
#       <td id="T_a8573_row4_col2" class="data row4 col2" >1.400000</td>
#       <td id="T_a8573_row4_col3" class="data row4 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8573_row5_col0" class="data row5 col0" >5.400000</td>
#       <td id="T_a8573_row5_col1" class="data row5 col1" >3.900000</td>
#       <td id="T_a8573_row5_col2" class="data row5 col2" >1.700000</td>
#       <td id="T_a8573_row5_col3" class="data row5 col3" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8573_row6_col0" class="data row6 col0" >4.600000</td>
#       <td id="T_a8573_row6_col1" class="data row6 col1" >3.400000</td>
#       <td id="T_a8573_row6_col2" class="data row6 col2" >1.400000</td>
#       <td id="T_a8573_row6_col3" class="data row6 col3" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8573_row7_col0" class="data row7 col0" >5.000000</td>
#       <td id="T_a8573_row7_col1" class="data row7 col1" >3.400000</td>
#       <td id="T_a8573_row7_col2" class="data row7 col2" >1.500000</td>
#       <td id="T_a8573_row7_col3" class="data row7 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8573_row8_col0" class="data row8 col0" >4.400000</td>
#       <td id="T_a8573_row8_col1" class="data row8 col1" >2.900000</td>
#       <td id="T_a8573_row8_col2" class="data row8 col2" >1.400000</td>
#       <td id="T_a8573_row8_col3" class="data row8 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8573_row9_col0" class="data row9 col0" >4.900000</td>
#       <td id="T_a8573_row9_col1" class="data row9 col1" >3.100000</td>
#       <td id="T_a8573_row9_col2" class="data row9 col2" >1.500000</td>
#       <td id="T_a8573_row9_col3" class="data row9 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8573_row10_col0" class="data row10 col0" >5.400000</td>
#       <td id="T_a8573_row10_col1" class="data row10 col1" >3.700000</td>
#       <td id="T_a8573_row10_col2" class="data row10 col2" >1.500000</td>
#       <td id="T_a8573_row10_col3" class="data row10 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8573_row11_col0" class="data row11 col0" >4.800000</td>
#       <td id="T_a8573_row11_col1" class="data row11 col1" >3.400000</td>
#       <td id="T_a8573_row11_col2" class="data row11 col2" >1.600000</td>
#       <td id="T_a8573_row11_col3" class="data row11 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8573_row12_col0" class="data row12 col0" >4.800000</td>
#       <td id="T_a8573_row12_col1" class="data row12 col1" >3.000000</td>
#       <td id="T_a8573_row12_col2" class="data row12 col2" >1.400000</td>
#       <td id="T_a8573_row12_col3" class="data row12 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a8573_row13_col0" class="data row13 col0" >4.300000</td>
#       <td id="T_a8573_row13_col1" class="data row13 col1" >3.000000</td>
#       <td id="T_a8573_row13_col2" class="data row13 col2" >1.100000</td>
#       <td id="T_a8573_row13_col3" class="data row13 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a8573_row14_col0" class="data row14 col0" >5.800000</td>
#       <td id="T_a8573_row14_col1" class="data row14 col1" >4.000000</td>
#       <td id="T_a8573_row14_col2" class="data row14 col2" >1.200000</td>
#       <td id="T_a8573_row14_col3" class="data row14 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a8573_row15_col0" class="data row15 col0" >5.700000</td>
#       <td id="T_a8573_row15_col1" class="data row15 col1" >4.400000</td>
#       <td id="T_a8573_row15_col2" class="data row15 col2" >1.500000</td>
#       <td id="T_a8573_row15_col3" class="data row15 col3" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a8573_row16_col0" class="data row16 col0" >5.400000</td>
#       <td id="T_a8573_row16_col1" class="data row16 col1" >3.900000</td>
#       <td id="T_a8573_row16_col2" class="data row16 col2" >1.300000</td>
#       <td id="T_a8573_row16_col3" class="data row16 col3" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a8573_row17_col0" class="data row17 col0" >5.100000</td>
#       <td id="T_a8573_row17_col1" class="data row17 col1" >3.500000</td>
#       <td id="T_a8573_row17_col2" class="data row17 col2" >1.400000</td>
#       <td id="T_a8573_row17_col3" class="data row17 col3" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a8573_row18_col0" class="data row18 col0" >5.700000</td>
#       <td id="T_a8573_row18_col1" class="data row18 col1" >3.800000</td>
#       <td id="T_a8573_row18_col2" class="data row18 col2" >1.700000</td>
#       <td id="T_a8573_row18_col3" class="data row18 col3" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a8573_level0_row19" class="row_heading level0 row19" >19</th>
